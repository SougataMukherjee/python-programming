# %%
import pandas as pd
data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [24, 30, 18]
}
df = pd.DataFrame(data)

print("Our DataFrame:")
print(df)

print("\nAverage Age:", df["Age"].mean())
# Out:
# Our DataFrame:
#       Name  Age
# 0    Alice   24
# 1      Bob   30
# 2  Charlie   18
#
# Average Age: 24.0
